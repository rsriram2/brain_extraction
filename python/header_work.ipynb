# %%
import pandas as pd

methods = ['v1', 'robust', 'synthstrip', 'hdctbet', 'ctbet', 'brainchop', 'dockerctbet']
prefixes = ("6046", "6084", "6096", "6246", "6315", "6342", "6499")

for method in methods:
    df = pd.read_csv(f"/Users/rushil/ichseg/{method}/annotations.csv")
    # count how many filenames start with any of the prefixes
    cnt = df['Filename'].str.startswith(prefixes).sum()
    print(f"{method}: {cnt} files match the prefixes")
# Out:
# v1: 47 files match the prefixes
# robust: 47 files match the prefixes
# synthstrip: 47 files match the prefixes
# hdctbet: 47 files match the prefixes
# ctbet: 22 files match the prefixes
# brainchop: 47 files match the prefixes
# dockerctbet: 47 files match the prefixes

# %%
import pandas as pd
result = pd.read_csv("/Users/rushil/Downloads/header_data.csv")
exclude = [6046, 6084, 6096, 6246, 6315, 6342, 6499]
out = result[~result['id_patient_short'].isin(exclude)].copy()

out['patient_id'] = out['dir_series'].str.extract(r'(\d+-\d+)')

# 2b) or, if you want it as a DataFrame:
counts_df = (
    out
    .groupby('patient_id')
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
)
counts_df
# Out:
# /var/folders/mj/t4xh15z52jz47tfwjlckghkc0000gn/T/ipykernel_26831/2380655299.py:2: DtypeWarning: Columns (59,77,90,105,121,122,126,127,128,132,134,149,151,155,172,173,186,187,188,191,238,248,251,252,254,255,256,257,258,260,261,262,263,265,266,269,273,274,276,280,282,283,284,287,288,289,298,301,302,303,310,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = pd.read_csv("/Users/rushil/Downloads/header_data.csv")
#     patient_id  count
# 349   6356-154     19
# 336   6343-214     19
# 387   6394-143     18
# 393   6400-223     17
# 439   6446-280     17
# ..         ...    ...
# 305   6310-320      4
# 4     6005-230      4
# 287   6292-216      3
# 48    6050-296      3
# 164   6168-341      1
#
# [499 rows x 2 columns]

# %%
import pandas as pd

# 1) load your annotations
df = pd.read_csv("/Users/rushil/ichseg/robust/annotations.csv")

# 2) pull out the numeric patient‐short (e.g. “6022” from “6022-240_…”)
df["id_patient_short"] = (
    df["Filename"].str.extract(r"^(\d+)", expand=False)
      .astype(int)
)

# 3) drop the unwanted patients
exclude = [6046, 6084, 6096, 6246, 6315, 6342, 6499]
df = df[~df["id_patient_short"].isin(exclude)]

# 4) now extract the full patient‐series ID and count
df["patient_id"] = df["Filename"].str.extract(r"^(\d+-\d+)", expand=False)
counts = df["patient_id"].value_counts().reset_index()
counts.columns = ["patient_id", "count"]

counts
# Out:
#     patient_id  count
# 0     6356-154     19
# 1     6343-214     19
# 2     6394-143     18
# 3     6400-223     17
# 4     6446-280     17
# ..         ...    ...
# 494   6005-230      4
# 495   6310-320      4
# 496   6050-296      3
# 497   6292-216      3
# 498   6168-341      1
#
# [499 rows x 2 columns]

# %%
import pandas as pd

# assume you already have these two DataFrames:
# counts_df  → columns ['patient_id','count']  from header_data.csv
# counts     → columns ['patient_id','count']  from annotations.csv

# 1) rename the count columns so they don’t clash
hdr = counts_df.rename(columns={'count':'hdr_count'})
ann = counts   .rename(columns={'count':'ann_count'})

# 2) outer‐join on patient_id
cmp = (hdr
       .merge(ann, on='patient_id', how='outer')
       .fillna(0)
    )

# ensure integers
cmp['hdr_count'] = cmp['hdr_count'].astype(int)
cmp['ann_count'] = cmp['ann_count'].astype(int)

# 3) find mismatches
mismatch = cmp[cmp['hdr_count'] != cmp['ann_count']]

print("These patient_ids have different counts (header vs annotation):")
print(mismatch)
# Out:
# These patient_ids have different counts (header vs annotation):
#     patient_id  hdr_count  ann_count
# 72    6109-317         13         12
# 77    6480-154         13         12
# 105   6193-324         12         11
# 183   6470-296         11         10
# 246   6142-308         10          9
# 318   6418-193          9          8
# 418   6257-335          8          7

# %%
import pandas as pd

# 1) Load both tables
hdr = pd.read_csv("/Users/rushil/Downloads/header_data.csv", low_memory=False)
ann = pd.read_csv("/Users/rushil/ichseg/robust/annotations.csv")

# 2) Re‑derive the same `patient_id` and “base” filename in each
hdr["patient_id"] = hdr["dir_series"].str.extract(r"(\d+-\d+)")
# pull just the filename (no path), swap .nii.gz → .png
hdr["base_file"] = (
    hdr["file_nifti"]
      .str.extract(r"([^/]+)\.nii\.gz$")[0]
      .astype(str)
      + ".png"
)

ann["patient_id"] = ann["Filename"].str.extract(r"^(\d+-\d+)")
ann["base_file"]  = ann["Filename"]

# 3) Your 7 mismatched IDs
mismatch_ids = ["6109-317","6480-154","6193-324","6470-296",
                "6142-308","6418-193","6257-335"]

# 4) Compute “header minus annotation” for each ID
missing = {}
for pid in mismatch_ids:
    hdr_set = set(hdr.loc[hdr["patient_id"]==pid, "base_file"])
    ann_set = set(ann.loc[ann["patient_id"]==pid,   "base_file"])
    missing[pid] = sorted(hdr_set - ann_set)

# 5) Display results
for pid, files in missing.items():
    print(f"{pid}: {len(files)} missing → {files}")
# Out:
# 6109-317: 1 missing → ['6109-317_20150302_0647_ct.png']
# 6480-154: 1 missing → ['6480-154_20170622_0937_ct.png']
# 6193-324: 1 missing → ['6193-324_20150924_1431_ct.png']
# 6470-296: 1 missing → ['6470-296_20170602_0607_ct.png']
# 6142-308: 1 missing → ['6142-308_20150610_0707_ct.png']
# 6418-193: 1 missing → ['6418-193_20161228_1248_ct.png']
# 6257-335: 1 missing → ['6257-335_20160118_1150_ct.png']

# %%
# List of missing files to remove
missing_files_to_remove = [
    '6109-317_20150302_0647_ct.png',
    '6480-154_20170622_0937_ct.png', 
    '6193-324_20150924_1431_ct.png',
    '6470-296_20170602_0607_ct.png',
    '6142-308_20150610_0707_ct.png',
    '6418-193_20161228_1248_ct.png',
    '6257-335_20160118_1150_ct.png'
]

print("Before removal:")
for pid in mismatch_ids:
    print(f"\n{pid} - Header data:")
    print(hdr[hdr["patient_id"] == pid][["patient_id", "base_file", "dir_series"]])

# Remove the missing files from hdr dataframe
hdr_cleaned = hdr[~hdr["base_file"].isin(missing_files_to_remove)].copy()

print("\n" + "="*50)
print("After removal:")
for pid in mismatch_ids:
    print(f"\n{pid} - Header data (cleaned):")
    remaining_rows = hdr_cleaned[hdr_cleaned["patient_id"] == pid][["patient_id", "base_file", "dir_series"]]
    print(remaining_rows)
    print(f"Count: {len(remaining_rows)}")

# Verify the counts now match
print("\n" + "="*50)
print("Verification - counts should now match:")
for pid in mismatch_ids:
    hdr_count = len(hdr_cleaned[hdr_cleaned["patient_id"] == pid])
    ann_count = len(ann[ann["patient_id"] == pid])
    print(f"{pid}: Header={hdr_count}, Annotations={ann_count}, Match={hdr_count == ann_count}")
    
len(hdr_cleaned)
# Out:
# Before removal:
#
# 6109-317 - Header data:
#      patient_id                      base_file  \
# 1097   6109-317  6109-317_20150202_1547_ct.png
# 1098   6109-317  6109-317_20150202_2027_ct.png
# 1099   6109-317  6109-317_20150203_0511_ct.png
# 1100   6109-317  6109-317_20150204_0520_ct.png
# 1101   6109-317  6109-317_20150204_1748_ct.png
# 1102   6109-317  6109-317_20150205_1923_ct.png
# 1103   6109-317  6109-317_20150206_0528_ct.png
# 1104   6109-317  6109-317_20150207_0535_ct.png
# 1105   6109-317  6109-317_20150208_0812_ct.png
# 1106   6109-317  6109-317_20150208_1637_ct.png
# 1107   6109-317  6109-317_20150209_1218_ct.png
# 1108   6109-317  6109-317_20150210_0547_ct.png
# 1109   6109-317  6109-317_20150302_0647_ct.png
#
#                                                                                                                    dir_series
# 1097            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150202_1547/6109-317_CT_20150202_1547
# 1098            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150202_2027/6109-317_CT_20150202_2029
# 1099            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150203_0511/6109-317_CT_20150203_0512
# 1100            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150204_0520/6109-317_CT_20150204_0522
# 1101            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150204_1748/6109-317_CT_20150204_1749
# 1102            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150205_1923/6109-317_CT_20150205_1926
# 1103            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150206_0528/6109-317_CT_20150206_0531
# 1104            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150207_0535/6109-317_CT_20150207_0536
# 1105            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150208_0812/6109-317_CT_20150208_0813
# 1106            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150208_1637/6109-317_CT_20150208_1638
# 1107            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150209_1218/6109-317_CT_20150209_1219
# 1108            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150210_0547/6109-317_CT_20150210_0548
# 1109  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150302_064738000000/6109-317_CT_20150302_064825
#
# 6480-154 - Header data:
#      patient_id                      base_file  \
# 4843   6480-154  6480-154_20170530_1536_ct.png
# 4844   6480-154  6480-154_20170530_2114_ct.png
# 4845   6480-154  6480-154_20170531_0559_ct.png
# 4846   6480-154  6480-154_20170601_0156_ct.png
# 4847   6480-154  6480-154_20170601_1847_ct.png
# 4848   6480-154  6480-154_20170602_0556_ct.png
# 4849   6480-154  6480-154_20170602_2036_ct.png
# 4850   6480-154  6480-154_20170603_1151_ct.png
# 4851   6480-154  6480-154_20170603_2354_ct.png
# 4852   6480-154  6480-154_20170604_0929_ct.png
# 4853   6480-154  6480-154_20170605_0118_ct.png
# 4854   6480-154  6480-154_20170606_1138_ct.png
# 4855   6480-154  6480-154_20170622_0937_ct.png
#
#                                                                                                                    dir_series
# 4843            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170530_1536/6480-154_CT_20170530_1537
# 4844            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170530_2114/6480-154_CT_20170530_2115
# 4845            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170531_0559/6480-154_CT_20170531_0601
# 4846            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170601_0156/6480-154_CT_20170601_0158
# 4847            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170601_1847/6480-154_CT_20170601_1848
# 4848            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170602_0556/6480-154_CT_20170602_0557
# 4849            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170602_2036/6480-154_CT_20170602_2037
# 4850            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170603_1151/6480-154_CT_20170603_1154
# 4851            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170603_2354/6480-154_CT_20170603_2355
# 4852            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170604_0929/6480-154_CT_20170604_0930
# 4853            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170605_0118/6480-154_CT_20170605_0119
# 4854            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170606_1138/6480-154_CT_20170606_1139
# 4855  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170622_093750000/6480-154_CT_20170622_094215125
#
# 6193-324 - Header data:
#      patient_id                      base_file  \
# 1918   6193-324  6193-324_20150901_0801_ct.png
# 1919   6193-324  6193-324_20150901_1502_ct.png
# 1920   6193-324  6193-324_20150903_1516_ct.png
# 1921   6193-324  6193-324_20150904_0449_ct.png
# 1922   6193-324  6193-324_20150904_1549_ct.png
# 1923   6193-324  6193-324_20150905_0439_ct.png
# 1924   6193-324  6193-324_20150906_0437_ct.png
# 1925   6193-324  6193-324_20150907_0137_ct.png
# 1926   6193-324  6193-324_20150907_0751_ct.png
# 1927   6193-324  6193-324_20150908_0509_ct.png
# 1928   6193-324  6193-324_20150909_1142_ct.png
# 1929   6193-324  6193-324_20150924_1431_ct.png
#
#                                                                                                                          dir_series
# 1918        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150901_080139/6193-324_CT_20150901_080455290000
# 1919                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150901_1502/6193-324_CT_20150901_1505
# 1920                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150903_1516/6193-324_CT_20150903_1516
# 1921                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150904_0449/6193-324_CT_20150904_0458
# 1922                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150904_1549/6193-324_CT_20150904_1551
# 1923                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150905_0439/6193-324_CT_20150905_0439
# 1924                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150906_0437/6193-324_CT_20150906_0437
# 1925                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150907_0137/6193-324_CT_20150907_0137
# 1926                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150907_0751/6193-324_CT_20150907_0751
# 1927                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150908_0509/6193-324_CT_20150908_0509
# 1928                  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150909_1142/6193-324_CT_20150909_1143
# 1929  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150924_143117578000/6193-324_CT_20150924_095702234000
#
# 6470-296 - Header data:
#      patient_id                      base_file  \
# 4732   6470-296  6470-296_20170510_0842_ct.png
# 4733   6470-296  6470-296_20170510_1823_ct.png
# 4734   6470-296  6470-296_20170511_0531_ct.png
# 4735   6470-296  6470-296_20170511_1643_ct.png
# 4736   6470-296  6470-296_20170511_1912_ct.png
# 4737   6470-296  6470-296_20170512_0535_ct.png
# 4738   6470-296  6470-296_20170512_2321_ct.png
# 4739   6470-296  6470-296_20170513_2308_ct.png
# 4740   6470-296  6470-296_20170514_2244_ct.png
# 4741   6470-296  6470-296_20170516_0121_ct.png
# 4742   6470-296  6470-296_20170602_0607_ct.png
#
#                                                                                                                          dir_series
# 4732  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170510_084203083000/6470-296_CT_20170510_084559419000
# 4733              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170510_182320/6470-296_CT_20170510_182433
# 4734  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170511_053102073000/6470-296_CT_20170511_055923807000
# 4735              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170511_164346/6470-296_CT_20170511_164714
# 4736  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170511_191237983000/6470-296_CT_20170511_191550493000
# 4737              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170512_053521/6470-296_CT_20170512_053640
# 4738  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170512_232114732000/6470-296_CT_20170512_232249854000
# 4739  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170513_230840535000/6470-296_CT_20170513_231020534000
# 4740  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170514_224421779000/6470-296_CT_20170514_224540080000
# 4741        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170516_012102253/6470-296_CT_20170516_012752675
# 4742              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170602_060713/6470-296_CT_20170602_060818
#
# 6142-308 - Header data:
#      patient_id                      base_file  \
# 1429   6142-308  6142-308_20150503_0901_ct.png
# 1430   6142-308  6142-308_20150503_1448_ct.png
# 1431   6142-308  6142-308_20150504_0359_ct.png
# 1432   6142-308  6142-308_20150505_1516_ct.png
# 1433   6142-308  6142-308_20150506_0409_ct.png
# 1434   6142-308  6142-308_20150507_0409_ct.png
# 1435   6142-308  6142-308_20150508_0337_ct.png
# 1436   6142-308  6142-308_20150509_0345_ct.png
# 1437   6142-308  6142-308_20150510_0455_ct.png
# 1438   6142-308  6142-308_20150610_0707_ct.png
#
#                                                                                                                    dir_series
# 1429            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150503_0901/6142-308_CT_20150503_0902
# 1430            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150503_1448/6142-308_CT_20150503_1448
# 1431            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150504_0359/6142-308_CT_20150504_0400
# 1432            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150505_1516/6142-308_CT_20150505_1518
# 1433            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150506_0409/6142-308_CT_20150506_0410
# 1434            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150507_0409/6142-308_CT_20150507_0410
# 1435            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150508_0337/6142-308_CT_20150508_0338
# 1436            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150509_0345/6142-308_CT_20150509_0345
# 1437            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150510_0455/6142-308_CT_20150510_0455
# 1438  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150610_070733000000/6142-308_CT_20150610_070831
#
# 6418-193 - Header data:
#      patient_id                      base_file  \
# 4201   6418-193  6418-193_20161211_2016_ct.png
# 4202   6418-193  6418-193_20161212_0003_ct.png
# 4203   6418-193  6418-193_20161212_0510_ct.png
# 4204   6418-193  6418-193_20161213_1601_ct.png
# 4205   6418-193  6418-193_20161214_0507_ct.png
# 4206   6418-193  6418-193_20161215_0416_ct.png
# 4207   6418-193  6418-193_20161216_0529_ct.png
# 4208   6418-193  6418-193_20161217_0204_ct.png
# 4209   6418-193  6418-193_20161228_1248_ct.png
#
#                                                                                                                          dir_series
# 4201  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161211_201633192000/6418-193_CT_20161211_201852404000
# 4202        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161212_000305126/6418-193_CT_20161212_000907982
# 4203        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161212_051014555/6418-193_CT_20161212_051607345
# 4204           /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161213_160111410/6418-193_CT_20161213_160329
# 4205        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161214_050758726/6418-193_CT_20161214_052056840
# 4206        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161215_041659413/6418-193_CT_20161215_042059623
# 4207        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161216_052951553/6418-193_CT_20161216_053208555
# 4208        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161217_020445959/6418-193_CT_20161217_020815119
# 4209              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161228_124801/6418-193_CT_20161228_124927
#
# 6257-335 - Header data:
#      patient_id                      base_file  \
# 2531   6257-335  6257-335_20151217_1431_ct.png
# 2532   6257-335  6257-335_20151217_2333_ct.png
# 2533   6257-335  6257-335_20151218_1613_ct.png
# 2534   6257-335  6257-335_20151220_0019_ct.png
# 2535   6257-335  6257-335_20151220_2240_ct.png
# 2536   6257-335  6257-335_20151222_1211_ct.png
# 2537   6257-335  6257-335_20160105_1052_ct.png
# 2538   6257-335  6257-335_20160118_1150_ct.png
#
#                                                                                                                    dir_series
# 2531            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151217_1431/6257-335_CT_20151217_1432
# 2532            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151217_2333/6257-335_CT_20151217_2334
# 2533            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151218_1613/6257-335_CT_20151218_1621
# 2534            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151220_0019/6257-335_CT_20151220_0019
# 2535            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151220_2240/6257-335_CT_20151220_2241
# 2536            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151222_1211/6257-335_CT_20151222_1214
# 2537            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20160105_1052/6257-335_CT_20160105_1156
# 2538  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20160118_115027000000/6257-335_CT_20160118_125353
#
# ==================================================
# After removal:
#
# 6109-317 - Header data (cleaned):
#      patient_id                      base_file  \
# 1097   6109-317  6109-317_20150202_1547_ct.png
# 1098   6109-317  6109-317_20150202_2027_ct.png
# 1099   6109-317  6109-317_20150203_0511_ct.png
# 1100   6109-317  6109-317_20150204_0520_ct.png
# 1101   6109-317  6109-317_20150204_1748_ct.png
# 1102   6109-317  6109-317_20150205_1923_ct.png
# 1103   6109-317  6109-317_20150206_0528_ct.png
# 1104   6109-317  6109-317_20150207_0535_ct.png
# 1105   6109-317  6109-317_20150208_0812_ct.png
# 1106   6109-317  6109-317_20150208_1637_ct.png
# 1107   6109-317  6109-317_20150209_1218_ct.png
# 1108   6109-317  6109-317_20150210_0547_ct.png
#
#                                                                                                          dir_series
# 1097  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150202_1547/6109-317_CT_20150202_1547
# 1098  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150202_2027/6109-317_CT_20150202_2029
# 1099  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150203_0511/6109-317_CT_20150203_0512
# 1100  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150204_0520/6109-317_CT_20150204_0522
# 1101  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150204_1748/6109-317_CT_20150204_1749
# 1102  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150205_1923/6109-317_CT_20150205_1926
# 1103  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150206_0528/6109-317_CT_20150206_0531
# 1104  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150207_0535/6109-317_CT_20150207_0536
# 1105  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150208_0812/6109-317_CT_20150208_0813
# 1106  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150208_1637/6109-317_CT_20150208_1638
# 1107  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150209_1218/6109-317_CT_20150209_1219
# 1108  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6109-317/6109-317_CT_20150210_0547/6109-317_CT_20150210_0548
# Count: 12
#
# 6480-154 - Header data (cleaned):
#      patient_id                      base_file  \
# 4843   6480-154  6480-154_20170530_1536_ct.png
# 4844   6480-154  6480-154_20170530_2114_ct.png
# 4845   6480-154  6480-154_20170531_0559_ct.png
# 4846   6480-154  6480-154_20170601_0156_ct.png
# 4847   6480-154  6480-154_20170601_1847_ct.png
# 4848   6480-154  6480-154_20170602_0556_ct.png
# 4849   6480-154  6480-154_20170602_2036_ct.png
# 4850   6480-154  6480-154_20170603_1151_ct.png
# 4851   6480-154  6480-154_20170603_2354_ct.png
# 4852   6480-154  6480-154_20170604_0929_ct.png
# 4853   6480-154  6480-154_20170605_0118_ct.png
# 4854   6480-154  6480-154_20170606_1138_ct.png
#
#                                                                                                          dir_series
# 4843  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170530_1536/6480-154_CT_20170530_1537
# 4844  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170530_2114/6480-154_CT_20170530_2115
# 4845  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170531_0559/6480-154_CT_20170531_0601
# 4846  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170601_0156/6480-154_CT_20170601_0158
# 4847  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170601_1847/6480-154_CT_20170601_1848
# 4848  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170602_0556/6480-154_CT_20170602_0557
# 4849  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170602_2036/6480-154_CT_20170602_2037
# 4850  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170603_1151/6480-154_CT_20170603_1154
# 4851  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170603_2354/6480-154_CT_20170603_2355
# 4852  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170604_0929/6480-154_CT_20170604_0930
# 4853  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170605_0118/6480-154_CT_20170605_0119
# 4854  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6480-154/6480-154_CT_20170606_1138/6480-154_CT_20170606_1139
# Count: 12
#
# 6193-324 - Header data (cleaned):
#      patient_id                      base_file  \
# 1918   6193-324  6193-324_20150901_0801_ct.png
# 1919   6193-324  6193-324_20150901_1502_ct.png
# 1920   6193-324  6193-324_20150903_1516_ct.png
# 1921   6193-324  6193-324_20150904_0449_ct.png
# 1922   6193-324  6193-324_20150904_1549_ct.png
# 1923   6193-324  6193-324_20150905_0439_ct.png
# 1924   6193-324  6193-324_20150906_0437_ct.png
# 1925   6193-324  6193-324_20150907_0137_ct.png
# 1926   6193-324  6193-324_20150907_0751_ct.png
# 1927   6193-324  6193-324_20150908_0509_ct.png
# 1928   6193-324  6193-324_20150909_1142_ct.png
#
#                                                                                                                    dir_series
# 1918  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150901_080139/6193-324_CT_20150901_080455290000
# 1919            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150901_1502/6193-324_CT_20150901_1505
# 1920            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150903_1516/6193-324_CT_20150903_1516
# 1921            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150904_0449/6193-324_CT_20150904_0458
# 1922            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150904_1549/6193-324_CT_20150904_1551
# 1923            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150905_0439/6193-324_CT_20150905_0439
# 1924            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150906_0437/6193-324_CT_20150906_0437
# 1925            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150907_0137/6193-324_CT_20150907_0137
# 1926            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150907_0751/6193-324_CT_20150907_0751
# 1927            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150908_0509/6193-324_CT_20150908_0509
# 1928            /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6193-324/6193-324_CT_20150909_1142/6193-324_CT_20150909_1143
# Count: 11
#
# 6470-296 - Header data (cleaned):
#      patient_id                      base_file  \
# 4732   6470-296  6470-296_20170510_0842_ct.png
# 4733   6470-296  6470-296_20170510_1823_ct.png
# 4734   6470-296  6470-296_20170511_0531_ct.png
# 4735   6470-296  6470-296_20170511_1643_ct.png
# 4736   6470-296  6470-296_20170511_1912_ct.png
# 4737   6470-296  6470-296_20170512_0535_ct.png
# 4738   6470-296  6470-296_20170512_2321_ct.png
# 4739   6470-296  6470-296_20170513_2308_ct.png
# 4740   6470-296  6470-296_20170514_2244_ct.png
# 4741   6470-296  6470-296_20170516_0121_ct.png
#
#                                                                                                                          dir_series
# 4732  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170510_084203083000/6470-296_CT_20170510_084559419000
# 4733              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170510_182320/6470-296_CT_20170510_182433
# 4734  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170511_053102073000/6470-296_CT_20170511_055923807000
# 4735              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170511_164346/6470-296_CT_20170511_164714
# 4736  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170511_191237983000/6470-296_CT_20170511_191550493000
# 4737              /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170512_053521/6470-296_CT_20170512_053640
# 4738  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170512_232114732000/6470-296_CT_20170512_232249854000
# 4739  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170513_230840535000/6470-296_CT_20170513_231020534000
# 4740  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170514_224421779000/6470-296_CT_20170514_224540080000
# 4741        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6470-296/6470-296_CT_20170516_012102253/6470-296_CT_20170516_012752675
# Count: 10
#
# 6142-308 - Header data (cleaned):
#      patient_id                      base_file  \
# 1429   6142-308  6142-308_20150503_0901_ct.png
# 1430   6142-308  6142-308_20150503_1448_ct.png
# 1431   6142-308  6142-308_20150504_0359_ct.png
# 1432   6142-308  6142-308_20150505_1516_ct.png
# 1433   6142-308  6142-308_20150506_0409_ct.png
# 1434   6142-308  6142-308_20150507_0409_ct.png
# 1435   6142-308  6142-308_20150508_0337_ct.png
# 1436   6142-308  6142-308_20150509_0345_ct.png
# 1437   6142-308  6142-308_20150510_0455_ct.png
#
#                                                                                                          dir_series
# 1429  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150503_0901/6142-308_CT_20150503_0902
# 1430  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150503_1448/6142-308_CT_20150503_1448
# 1431  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150504_0359/6142-308_CT_20150504_0400
# 1432  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150505_1516/6142-308_CT_20150505_1518
# 1433  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150506_0409/6142-308_CT_20150506_0410
# 1434  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150507_0409/6142-308_CT_20150507_0410
# 1435  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150508_0337/6142-308_CT_20150508_0338
# 1436  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150509_0345/6142-308_CT_20150509_0345
# 1437  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6142-308/6142-308_CT_20150510_0455/6142-308_CT_20150510_0455
# Count: 9
#
# 6418-193 - Header data (cleaned):
#      patient_id                      base_file  \
# 4201   6418-193  6418-193_20161211_2016_ct.png
# 4202   6418-193  6418-193_20161212_0003_ct.png
# 4203   6418-193  6418-193_20161212_0510_ct.png
# 4204   6418-193  6418-193_20161213_1601_ct.png
# 4205   6418-193  6418-193_20161214_0507_ct.png
# 4206   6418-193  6418-193_20161215_0416_ct.png
# 4207   6418-193  6418-193_20161216_0529_ct.png
# 4208   6418-193  6418-193_20161217_0204_ct.png
#
#                                                                                                                          dir_series
# 4201  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161211_201633192000/6418-193_CT_20161211_201852404000
# 4202        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161212_000305126/6418-193_CT_20161212_000907982
# 4203        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161212_051014555/6418-193_CT_20161212_051607345
# 4204           /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161213_160111410/6418-193_CT_20161213_160329
# 4205        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161214_050758726/6418-193_CT_20161214_052056840
# 4206        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161215_041659413/6418-193_CT_20161215_042059623
# 4207        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161216_052951553/6418-193_CT_20161216_053208555
# 4208        /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6418-193/6418-193_CT_20161217_020445959/6418-193_CT_20161217_020815119
# Count: 8
#
# 6257-335 - Header data (cleaned):
#      patient_id                      base_file  \
# 2531   6257-335  6257-335_20151217_1431_ct.png
# 2532   6257-335  6257-335_20151217_2333_ct.png
# 2533   6257-335  6257-335_20151218_1613_ct.png
# 2534   6257-335  6257-335_20151220_0019_ct.png
# 2535   6257-335  6257-335_20151220_2240_ct.png
# 2536   6257-335  6257-335_20151222_1211_ct.png
# 2537   6257-335  6257-335_20160105_1052_ct.png
#
#                                                                                                          dir_series
# 2531  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151217_1431/6257-335_CT_20151217_1432
# 2532  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151217_2333/6257-335_CT_20151217_2334
# 2533  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151218_1613/6257-335_CT_20151218_1621
# 2534  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151220_0019/6257-335_CT_20151220_0019
# 2535  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151220_2240/6257-335_CT_20151220_2241
# 2536  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20151222_1211/6257-335_CT_20151222_1214
# 2537  /Users/johnmuschelli/Desktop/mistie_3/data/dicom/6257-335/6257-335_CT_20160105_1052/6257-335_CT_20160105_1156
# Count: 7
#
# ==================================================
# Verification - counts should now match:
# 6109-317: Header=12, Annotations=12, Match=True
# 6480-154: Header=12, Annotations=12, Match=True
# 6193-324: Header=11, Annotations=11, Match=True
# 6470-296: Header=10, Annotations=10, Match=True
# 6142-308: Header=9, Annotations=9, Match=True
# 6418-193: Header=8, Annotations=8, Match=True
# 6257-335: Header=7, Annotations=7, Match=True
# 5109

# %%
hdr_cleaned.to_csv("/Users/rushil/ichseg/robust/header_data_cleaned.csv", index=False)
